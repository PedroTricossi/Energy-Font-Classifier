# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

arr =np.load('GLYPHS/train.npy')
arr
# Out:
# array([[[0.16731804, 0.16731804, 0.16731804, ..., 0.16731804,
#          0.16731804, 0.16731804],
#         [0.16731804, 0.16731804, 0.16731804, ..., 0.16731804,
#          0.16731804, 0.16731804],
#         [0.16731804, 0.16731804, 0.16731804, ..., 0.16731804,
#          0.16731804, 0.16731804],
#         ...,
#         [0.16731804, 0.16731804, 0.16731804, ..., 0.16731804,
#          0.16731804, 0.16731804],
#         [0.16731804, 0.16731804, 0.16731804, ..., 0.16731804,
#          0.16731804, 0.16731804],
#         [0.16731804, 0.16731804, 0.16731804, ..., 0.16731804,
#          0.16731804, 0.16731804]],
#
#        [[0.18245373, 0.18245373, 0.18245373, ..., 0.18245373,
#          0.18245373, 0.18245373],
#         [0.18245373, 0.18245373, 0.18245373, ..., 0.18245373,
#          0.18245373, 0.18245373],
#         [0.18245373, 0.18245373, 0.18245373, ..., 0.18245373,
#          0.18245373, 0.18245373],
#         ...,
#         [0.18245373, 0.18245373, 0.18245373, ..., 0.18245373,
# ...

# %%
plt.imshow(arr[1], cmap="gray")
